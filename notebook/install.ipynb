# %%
# !git clone --depth 1 https://github.com/danielmiessler/SecLists.git assets/wordlists
# Out:
# Cloning into 'assets/wordlists'...
# remote: Enumerating objects: 5489, done.
# remote: Counting objects: 100% (5489/5489), done.
# remote: Compressing objects: 100% (3036/3036), done.
# remote: Total 5489 (delta 2309), reused 5320 (delta 2305), pack-reused 0
# Receiving objects: 100% (5489/5489), 527.14 MiB | 7.44 MiB/s, done.
# Resolving deltas: 100% (2309/2309), done.
# Updating files: 100% (5454/5454), done.

# %%
# !openvpn assets/starting_point_boddicheg.ovpn
# Out:
# 2023-08-07 07:21:55 WARNING: Compression for receiving enabled. Compression has been used in the past to break encryption. Sent packets are not compressed unless "allow-compression yes" is also set.
# 2023-08-07 07:21:55 DEPRECATED OPTION: --cipher set to 'AES-128-CBC' but missing in --data-ciphers (AES-256-GCM:AES-128-GCM:CHACHA20-POLY1305). OpenVPN ignores --cipher for cipher negotiations.
# 2023-08-07 07:21:55 Note: '--allow-compression' is not set to 'no', disabling data channel offload.
# 2023-08-07 07:21:55 OpenVPN 2.6.3 x86_64-pc-linux-gnu [SSL (OpenSSL)] [LZO] [LZ4] [EPOLL] [PKCS11] [MH/PKTINFO] [AEAD] [DCO]
# 2023-08-07 07:21:55 library versions: OpenSSL 3.0.9 30 May 2023, LZO 2.10
# 2023-08-07 07:21:55 DCO version: N/A
# 2023-08-07 07:21:55 TCP/UDP: Preserving recently used remote address: [AF_INET]23.19.62.79:443
# 2023-08-07 07:21:55 Socket Buffers: R=[131072->131072] S=[16384->16384]
# ...

# %%
# APT packages
#!apt install git
#!apt install nmap

# %%
# !pip install pydig
# !pip install dnspython
# !pip install whois
# !pip install nslookup
# !pip install wafw00f
# !pip install geoip2
# !pip install python3-nmap
# Out:
# ...
#   Using cached pydig-0.4.0-py3-none-any.whl (16 kB)
# ...
#   Obtaining dependency information for dnspython from https://files.pythonhosted.org/packages/71/30/deee2ffb94194437c730a1c6230d9310ab5f73926a2549cdab91453616bb/dnspython-2.4.1-py3-none-any.whl.metadata
#   Using cached dnspython-2.4.1-py3-none-any.whl.metadata (4.9 kB)
# Using cached dnspython-2.4.1-py3-none-any.whl (300 kB)
# ...
#   Using cached whois-0.9.27-py3-none-any.whl
# ...
#   Using cached nslookup-1.7.0-py3-none-any.whl (9.2 kB)
# ...
#   Using cached wafw00f-2.2.0-py3-none-any.whl (90 kB)
# ...
#   Using cached pluginbase-1.0.1-py3-none-any.whl
# ...
#   Using cached geoip2-4.7.0-py2.py3-none-any.whl (26 kB)
# ...
#   Obtaining dependency information for aiohttp<4.0.0,>=3.6.2 from https://files.pythonhosted.org/packages/4c/b8/5c5efbb1d3cb1da3612b8e309e8e31b602ee9c5cca8e41961db385fc9d00/aiohttp-3.8.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...

# %%
# !git --version
# !pwd
# !git clone https://github.com/danielmiessler/SecLists.git assets/SecLists
# Out:
# git version 2.34.1
# /home/jovyan/recon
# Cloning into 'assets/SecLists'...
# remote: Enumerating objects: 12254, done.
# remote: Counting objects: 100% (1749/1749), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 12254 (delta 1669), reused 1625 (delta 1625), pack-reused 10505
# Receiving objects: 100% (12254/12254), 907.86 MiB | 7.01 MiB/s, done.
# Resolving deltas: 100% (6749/6749), done.
# Updating files: 100% (5454/5454), done.
